# %% [markdown]
# # NetworkX

# %% [markdown]
# > This notebook as been adapted from the [original notebook](https://github.com/jdwittenauer/ipython-notebooks/blob/master/NetworkX.ipynb) to plot with [Bokeh](bokeh.pydata.org) instead of matplotlib.
#
# NetworkX is a Python language software package for the creation, manipulation, and study of the structure, dynamics, and function of complex networks.
#
# With NetworkX you can load and store networks in standard and nonstandard data formats, generate many types of random and classic networks, analyze network structure, build network models, design new network algorithms, draw networks, and much more.
#
# Library documentation: <a>https://networkx.github.io/</a>

# %%
import networkx as nx
G = nx.Graph()

# %%
# basic add nodes
G.add_node(1)
G.add_nodes_from([2, 3])

# %%
# add a group of nodes at once
H = nx.path_graph(10)
G.add_nodes_from(H)

# %%
# add another graph itself as a node
G.add_node(H)

# %%
# add edges using similar methods
G.add_edge(1, 2)
e = (2, 3)
G.add_edge(*e)
G.add_edges_from([(1, 2), (1, 3)])
G.add_edges_from(H.edges())

# %%
# can also remove or clear
G.remove_node(H)
G.clear()

# %%
# repeats are ignored
G.add_edges_from([(1,2),(1,3)])
G.add_node(1)
G.add_edge(1,2)
G.add_node('spam')       # adds node "spam"
G.add_nodes_from('spam') # adds 4 nodes: 's', 'p', 'a', 'm'

# %%
# get the number of nodes and edges
G.number_of_nodes(), G.number_of_edges()
# Out:
# (8, 2)

# %%
# access graph edges
G[1]
# Out:
# {2: {}, 3: {}}

# %%
G[1][2]
# Out:
# {}

# %%
# set an attribute of an edge
G.add_edge(1,3)
G[1][3]['color'] = 'blue'

# %%
FG = nx.Graph()
FG.add_weighted_edges_from([(1, 2, 0.125), (1, 3, 0.75), (2, 4, 1.2), (3, 4, 0.375)])
for n, nbrs in FG.adjacency_iter():
    for nbr, eattr in nbrs.items():
        data = eattr['weight']
        if data < 0.5: print('(%d, %d, %.3f)' % (n, nbr, data))
# Out:
# (1, 2, 0.125)
# (2, 1, 0.125)
# (3, 4, 0.375)
# (4, 3, 0.375)

# %%
# graph attribte
G = nx.Graph(day='Friday')
G.graph
# Out:
# {'day': 'Friday'}

# %%
# modifying an attribute
G.graph['day'] = 'Monday'
G.graph
# Out:
# {'day': 'Monday'}

# %%
# node attributes
G.add_node(1, time='5pm')
G.add_nodes_from([3], time='2pm')
G.node[1]['room'] = 714
G.nodes(data=True)
# Out:
# [(1, {'room': 714, 'time': '5pm'}), (3, {'time': '2pm'})]

# %%
# edge attributes (weight is a special numeric attribute)
G.add_edge(1, 2, weight=4.7)
G.add_edges_from([(3, 4), (4, 5)], color='red')
G.add_edges_from([(1, 2 ,{'color': 'blue'}), (2, 3, {'weight' :8})])
G[1][2]['weight'] = 4.7
G.edge[1][2]['weight'] = 4

# %%
# directed graph
DG = nx.DiGraph()
DG.add_weighted_edges_from([(1, 2 ,0.5), (3, 1, 0.75)])
DG.out_degree(1, weight='weight')
# Out:
# 0.5

# %%
DG.degree(1, weight='weight')
# Out:
# 1.25

# %%
DG.successors(1)
# Out:
# [2]

# %%
DG.predecessors(1)
# Out:
# [3]

# %%
# convert to undirected graph
H = nx.Graph(G)

# %%
from bokeh.plotting import figure, show
from bokeh.resources import CDN
from bokeh.io import output_notebook
output_notebook( resources=CDN )
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c1f11f13-5a6b-4356-af46-47d46ab2acec">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Explore NetworkX Graph Layouts
#
# There are a few [layouts available in NetworkX graphs.](https://networkx.github.io/documentation/latest/reference/generated/networkx.drawing.layout.circular_layout.html)

# %% [markdown]
# ## Circular Layout

# %%
pts = nx.circular_layout(G)
p = figure(
    x_range = (-.1,1.1),
    y_range = (-.1,1.1),
    height= 400,
    width= 400,
)
for edge in G.edges():
    p.line( 
        x= [pts[pt][0] for pt in edge],
        y= [pts[pt][1] for pt in edge],
    )

for node in G.nodes():
    p.circle( 
        x= [pts[node][0]],
        y= [pts[node][1]],
        radius=.05
    )
show(p)
# Out:
#     <div class="plotdiv" id="829002ef-d2cd-49da-8307-9a5093f9f4b9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("829002ef-d2cd-49da-8307-9a5093f9f4b9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '829002ef-d2cd-49da-8307-9a5093f9f4b9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f486b9a5-9a2b-4c85-a12e-e045c7c3ba44":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c5b83d29-5803-412b-baab-54e4b3b607a6","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"af64c163-3877-4128-ba72-0f72596fdd2c","type":"Circle"},{"attributes":{},"id":"7a51760c-9bf1-4286-896a-a5da41a91ec8","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1ade317-3686-4c67-afed-4559cfde85ae","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"20bc79d7-5a39-4158-a2da-d5f54bbe9100","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"c92a9c97-37ec-4ea4-945c-fa5eb7efa34c","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8d977c6-6e81-4663-8859-0de42da8efc0","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1.0,0.30901699437494745],"y":[0.0,0.9510565162951535]}},"id":"bb10a174-e83e-47d9-8eba-23edeaadc0e5","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"}},"id":"9540e648-5214-4fbf-a50d-b1d3009f4017","type":"ResizeTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"c20aed83-c1cc-4edd-9bcc-80b62af7415f","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.30901699437494745,-0.8090169943749473],"y":[0.9510565162951535,0.5877852522924732]}},"id":"62a76a45-2b00-4d0e-b7d1-658dbe59c2c5","type":"ColumnDataSource"},{"attributes":{},"id":"cbb1cfbd-4fc0-4de7-89f7-8242f62b8b07","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61b17f4d-e91b-448b-b037-8384aef68da4","type":"Line"},{"attributes":{"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"}},"id":"a1eb826f-ab5a-48a9-be0d-6740e11ac1de","type":"PanTool"},{"attributes":{"data_source":{"id":"bb10a174-e83e-47d9-8eba-23edeaadc0e5","type":"ColumnDataSource"},"glyph":{"id":"c1ade317-3686-4c67-afed-4559cfde85ae","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1be4b6c2-f9e6-4a16-9549-cef654a376c9","type":"Line"},"selection_glyph":null},"id":"daaaefef-93a8-4f4a-a469-12f4e0500a96","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749476,0.30901699437494723],"y":[-0.587785252292473,-0.9510565162951536]}},"id":"1c24c5f9-fced-42cc-a809-78a907c2da66","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"a1054243-69a6-4b55-a8e5-7216c9f25fd7","type":"BasicTickFormatter"},"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a51760c-9bf1-4286-896a-a5da41a91ec8","type":"BasicTicker"}},"id":"bf5e5547-a29f-4d08-84f0-c822f0543508","type":"LinearAxis"},{"attributes":{"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"}},"id":"b73b1200-b033-405d-9e3c-735e2acb1320","type":"PreviewSaveTool"},{"attributes":{"fill_alph ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[23]</strong>&gt;</code></p>

# %% [markdown]
# ## Random Layout

# %%
pts = nx.random_layout(G)
p = figure(
    x_range = (-.1,1.1),
    y_range = (-.1,1.1),
    height= 400,
    width= 400,
)
for edge in G.edges():
    p.line( 
        x= [pts[pt][0] for pt in edge],
        y= [pts[pt][1] for pt in edge],
    )

for node in G.nodes():
    p.circle( 
        x= [pts[node][0]],
        y= [pts[node][1]],
        radius=.05
    )
show(p)
# Out:
#     <div class="plotdiv" id="20ea7045-9054-4262-99ac-97f666b3ea9f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("20ea7045-9054-4262-99ac-97f666b3ea9f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '20ea7045-9054-4262-99ac-97f666b3ea9f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ed2d133b-9ef2-4d7e-8481-0a1f5913c849":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"af64c163-3877-4128-ba72-0f72596fdd2c","type":"Circle"},{"attributes":{"plot":{"id":"da29d2f5-7bf2-43a1-bfa4-c7c201c22193","subtype":"Figure","type":"Plot"}},"id":"f9dd48b7-97f3-4bf3-ad38-d9e21c60dbfe","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.705545881846073],"y":[0.6332586420530256]}},"id":"db68a79c-c0f4-4d5f-8b94-75ab967e20fc","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c1ade317-3686-4c67-afed-4559cfde85ae","type":"Line"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"c92a9c97-37ec-4ea4-945c-fa5eb7efa34c","type":"Circle"},{"attributes":{},"id":"5f030d05-c8d0-49b7-969c-2dd9199a03d4","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8d977c6-6e81-4663-8859-0de42da8efc0","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d004b1b7-bace-49b2-af17-c7c82722be53","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1.0,0.30901699437494745],"y":[0.0,0.9510565162951535]}},"id":"bb10a174-e83e-47d9-8eba-23edeaadc0e5","type":"ColumnDataSource"},{"attributes":{},"id":"f87c3618-3823-4817-b1ee-1937c55a0ac5","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0606674271493437,0.705545881846073],"y":[0.03035537500342722,0.6332586420530256]}},"id":"a7d89173-1e21-4238-9a15-2dd40e5e37a8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f76c0d6a-13d8-42bc-ae1d-5f3ef5338cb2","type":"ColumnDataSource"},"glyph":{"id":"18079b11-0631-4770-b968-e4e52e92a31c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dcb6accb-3a56-41f7-b613-469c54fc3dfb","type":"Line"},"selection_glyph":null},"id":"90b19020-1c9e-4a4f-8f9e-611c114da4ed","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d42e9cda-579c-4d08-9e4a-6e837a5c86e6","type":"ColumnDataSource"},"glyph":{"id":"21e65cd8-624f-4779-8715-07ef5a04efe4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"46efca0f-1bae-4a4a-9569-23ccb50c2d2c","type":"Circle"},"selection_glyph":null},"id":"507f8116-e217-46ba-b600-3a1ea8e1c45f","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"7558be05-069e-4124-bad5-64d020371b97","type":"BasicTickFormatter"},"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"},"ticker":{"id":"cbb1cfbd-4fc0-4de7-89f7-8242f62b8b07","type":"BasicTicker"}},"id":"98f093b5-97c8-4616-a298-5a49fd080243","type":"LinearAxis"},{"attributes":{"plot":{"id":"da29d2f5-7bf2-43a1-bfa4-c7c201c22193","subtype":"Figure","type":"Plot"}},"id":"f5ee2d5b-8ecf-4cb8-9637-87d97cc8be04","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c8c5326-94dc-4944-9735-1bcd3eb19176","type":"Line"},{"attributes":{"data_source":{"id":"bb10a174-e83e-47d9-8eba-23edeaadc0e5","type":"ColumnDataSource"},"glyph":{"id":"c1ade317-3686-4c67-afed-4559cfde85ae","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1be4b6c2-f9e6-4a16-9549-cef654a376c9","type":"Line"},"selection_glyph":null},"id":"daaaefef-93a8-4f4a-a469-12f4e0500a96","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"a1054243-69a6-4b55-a8e5-7216c9f25fd7","type":"BasicTickFormatter"},"plot":{"id":"397a5bc9-4895-481a-a2ef-8d5f262eb4bd","subtype":"Figure","type":"Plot"},"ti ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[24]</strong>&gt;</code></p>

# %% [markdown]
# ## Shell Layout

# %%
pts = nx.shell_layout(G)
p = figure(
    x_range = (-1.1,1.1),
    y_range = (-1.1,1.1),
    height= 400,
    width= 400,
)
for edge in G.edges():
    p.line( 
        x= [pts[pt][0] for pt in edge],
        y= [pts[pt][1] for pt in edge],
    )

for node in G.nodes():
    p.circle( 
        x= [pts[node][0]],
        y= [pts[node][1]],
        radius=.05
    )
show(p)
# Out:
#     <div class="plotdiv" id="e5310840-2af5-4bd2-829b-4e03d68ac35d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e5310840-2af5-4bd2-829b-4e03d68ac35d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e5310840-2af5-4bd2-829b-4e03d68ac35d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"026a9b32-c090-4226-808d-3e2ae8acfda4":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"af64c163-3877-4128-ba72-0f72596fdd2c","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749476,0.30901699437494723],"y":[-0.587785252292473,-0.9510565162951536]}},"id":"1c24c5f9-fced-42cc-a809-78a907c2da66","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"da29d2f5-7bf2-43a1-bfa4-c7c201c22193","subtype":"Figure","type":"Plot"}},"id":"f9dd48b7-97f3-4bf3-ad38-d9e21c60dbfe","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.705545881846073],"y":[0.6332586420530256]}},"id":"db68a79c-c0f4-4d5f-8b94-75ab967e20fc","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"1fbbf521-0b91-4e32-b108-e0a4b2070e41","type":"Circle"},{"attributes":{},"id":"6daadc7c-3147-4b70-8537-a8657b063c69","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749473],"y":[0.5877852522924732]}},"id":"63fc497a-59c4-44f2-b561-99127fa9097f","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"a129c869-e14c-4fd7-8d70-54266f07fcce","type":"LinearAxis"}],"left":[{"id":"cf068ab5-1d02-4dea-af78-75e79fa2101a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a129c869-e14c-4fd7-8d70-54266f07fcce","type":"LinearAxis"},{"id":"ca79005e-88c9-4a66-9354-3cb361bcd51b","type":"Grid"},{"id":"cf068ab5-1d02-4dea-af78-75e79fa2101a","type":"LinearAxis"},{"id":"32e5a9a2-2679-4e8a-8041-42642a615c29","type":"Grid"},{"id":"8411c04a-e964-444c-bed1-26a1a93ff6f7","type":"BoxAnnotation"},{"id":"34bf9a01-faec-4002-af09-2e94db7847a7","type":"GlyphRenderer"},{"id":"3c54495f-4791-4791-89c7-f0b9205d1445","type":"GlyphRenderer"},{"id":"517acef6-df57-47cd-a4dc-f3f804104282","type":"GlyphRenderer"},{"id":"9bb330cc-a59a-4c74-9f63-723ebbec857d","type":"GlyphRenderer"},{"id":"3f52e94b-839e-46c7-84a6-d8511e58ce30","type":"GlyphRenderer"},{"id":"4396ea7b-6299-414f-8a4a-03f4c6517601","type":"GlyphRenderer"},{"id":"b76bc10e-70b0-4dc5-85ee-00e0d27a6eb3","type":"GlyphRenderer"},{"id":"0ccf58f8-24e0-4207-974d-ba2be718804d","type":"GlyphRenderer"},{"id":"64270ad2-1c3f-4669-bf65-ea97f6265644","type":"GlyphRenderer"}],"tool_events":{"id":"1ba8130a-b2eb-43c5-9e4b-30e1feb45265","type":"ToolEvents"},"tools":[{"id":"e4da0fe9-0f42-464f-8f00-6a6523e9fedf","type":"PanTool"},{"id":"91a64107-9d02-4fa8-8751-a8b6285e7419","type":"WheelZoomTool"},{"id":"7ebf771f-4a19-46d4-84aa-7ac2d25ddfd8","type":"BoxZoomTool"},{"id":"37ea7338-9cd2-4a33-ac2b-534da3c51986","type":"PreviewSaveTool"},{"id":"24e64443-6228-4591-aa0d-3e58527ce07e","type":"ResizeTool"},{"id":"fc2f5f76-e7e2-4371-b733-e38d01fbbbbf","type":"ResetTool"},{"id":"46d3d2db-f486-4d1d-b22a-9e2ee82fbb4d","type":"HelpTool"}],"x_range":{"id":"83197e18-1463-47f8-98f6-72ca3ef13287","type":"Range1d"},"y_range":{"id":"2b7c6469-f8a7-4f96-85ae-68358af74466","type":"Range1d"}},"id":"0971faa4-07a3-4057-9355-3edb1fa4900e","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8d977c6-6e81-4663-8859-0de42da8efc0","type":"Circle"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d004b1b7-bace-49b2-af17-c7c82722be53","type":"Line"},{"attributes":{"plot":{"id":"0971faa4-07a3-4057-9355-3edb1fa4900e","subtype":"Figure","type":"Plot"}},"id":"46d3d2db-f486-4d1d-b22a-9e2ee82fbb4d","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1.0,0.30 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[25]</strong>&gt;</code></p>

# %% [markdown]
# ## Spring Layout

# %%
pts = nx.spring_layout(G)
p = figure(
    x_range = (-.1,1.1),
    y_range = (-.1,1.1),
    height= 400,
    width= 400,
)
for edge in G.edges():
    p.line( 
        x= [pts[pt][0] for pt in edge],
        y= [pts[pt][1] for pt in edge],
    )

for node in G.nodes():
    p.circle( 
        x= [pts[node][0]],
        y= [pts[node][1]],
        radius=.05,
    )
show(p)
# Out:
#     <div class="plotdiv" id="9711ee6c-eed4-421b-8180-156cf09edb96"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9711ee6c-eed4-421b-8180-156cf09edb96");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9711ee6c-eed4-421b-8180-156cf09edb96' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"26178cd1-98c7-4e06-85cc-5da099ce1467":{"roots":{"references":[{"attributes":{"below":[{"id":"d90e5f32-cbc8-47fa-8690-842a69aab236","type":"LinearAxis"}],"left":[{"id":"deed35b8-e74f-43f1-83cf-5e202fa570e4","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"d90e5f32-cbc8-47fa-8690-842a69aab236","type":"LinearAxis"},{"id":"25aefd42-15c9-43a8-ba35-4edab30b2a14","type":"Grid"},{"id":"deed35b8-e74f-43f1-83cf-5e202fa570e4","type":"LinearAxis"},{"id":"a8f1de68-d90d-4cf8-8088-13baefb60a33","type":"Grid"},{"id":"6073a181-23c6-4545-a0d1-b623a7ad7540","type":"BoxAnnotation"},{"id":"ac2e4303-43bb-4f54-8085-570172ef8535","type":"GlyphRenderer"},{"id":"4c04e782-6dc0-4330-9e9d-71b3996e3223","type":"GlyphRenderer"},{"id":"d9651dfe-1dc1-46a0-be26-09e7ef3ae141","type":"GlyphRenderer"},{"id":"b6dcc38a-0525-4f7b-a13d-a1f7c63dc090","type":"GlyphRenderer"},{"id":"b6a5ca35-6f85-4bea-988a-f44265db3206","type":"GlyphRenderer"},{"id":"5cfac125-5e94-449a-a66a-dbdfdebfda2f","type":"GlyphRenderer"},{"id":"319978df-24c3-4d49-acb1-fdf9828ecdfc","type":"GlyphRenderer"},{"id":"fe6aadc3-b075-4267-819e-d291cf4be3a7","type":"GlyphRenderer"},{"id":"389c8ba6-73b7-4d09-b950-2d4831b39f8c","type":"GlyphRenderer"}],"tool_events":{"id":"cc72c9b6-d1cf-4188-9988-75bb05d370ce","type":"ToolEvents"},"tools":[{"id":"24805212-61cb-4300-b04f-14611cf6f294","type":"PanTool"},{"id":"d937e7d0-56a4-4d4b-964a-1ceb94cff4e5","type":"WheelZoomTool"},{"id":"c3c784a9-0b12-49b6-9117-13c07b330ea2","type":"BoxZoomTool"},{"id":"913510d8-6f69-4cc7-a846-c6737e6c9f37","type":"PreviewSaveTool"},{"id":"1fa941fd-f1e7-4b92-bce1-b4ee2b669a00","type":"ResizeTool"},{"id":"44076a2b-e677-4842-9b11-3b7b8ab18bf4","type":"ResetTool"},{"id":"bd860acf-e262-479c-8d7b-60e484397871","type":"HelpTool"}],"x_range":{"id":"8eb989d9-9cb2-425b-90b0-9e7393c472d2","type":"Range1d"},"y_range":{"id":"bea29950-6e1d-4849-8125-899f95f0ba68","type":"Range1d"}},"id":"042c498a-8d73-4b0a-bdcd-0998693754d2","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"042c498a-8d73-4b0a-bdcd-0998693754d2","subtype":"Figure","type":"Plot"}},"id":"1fa941fd-f1e7-4b92-bce1-b4ee2b669a00","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749473],"y":[0.5877852522924732]}},"id":"63fc497a-59c4-44f2-b561-99127fa9097f","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"af64c163-3877-4128-ba72-0f72596fdd2c","type":"Circle"},{"attributes":{},"id":"1ba8130a-b2eb-43c5-9e4b-30e1feb45265","type":"ToolEvents"},{"attributes":{},"id":"f87c3618-3823-4817-b1ee-1937c55a0ac5","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4eff67ce-1a14-4c19-ac5b-fe721175df4f","type":"Line"},{"attributes":{"data_source":{"id":"d42e9cda-579c-4d08-9e4a-6e837a5c86e6","type":"ColumnDataSource"},"glyph":{"id":"21e65cd8-624f-4779-8715-07ef5a04efe4","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"46efca0f-1bae-4a4a-9569-23ccb50c2d2c","type":"Circle"},"selection_glyph":null},"id":"507f8116-e217-46ba-b600-3a1ea8e1c45f","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7b31b72f-51da-4f75-9484-56b61d9132bc","type":"Line"},{"attributes":{"overlay":{"id":"8411c04a-e964-444c-bed1-26a1a93ff6f7","type":"BoxAnnotation"},"plot":{"id":"0971faa4-07a3-4057-9355-3edb1fa4900e","subtype":"Figure","type":"Plot"}},"id":"7ebf771f-4a19-46d4-84aa-7ac2d25ddfd8","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb25db82-cc3c-4bca-9efb-7e16b14a4e2a","type":"Circle"},{"attributes":{"callback":null,"end":1.1,"start":-0.1},"id":"8eb989d9-9cb2-425b-9 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[26]</strong>&gt;</code></p>

# %% [markdown]
# ## Spectral Layout

# %%
pts = nx.spectral_layout(G)
p = figure(
    x_range = (-.1,1.1),
    y_range = (-.1,1.1),
    height= 400,
    width= 400,
)
for edge in G.edges():
    p.line( 
        x= [pts[pt][0] for pt in edge],
        y= [pts[pt][1] for pt in edge],
    )

for node in G.nodes():
    p.circle( 
        x= [pts[node][0]],
        y= [pts[node][1]],
        radius=.05,
    )
show(p)
# Out:
#     <div class="plotdiv" id="eb3fe00b-3b4f-440c-b050-80d37cc5452e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eb3fe00b-3b4f-440c-b050-80d37cc5452e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eb3fe00b-3b4f-440c-b050-80d37cc5452e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"813270d7-6d8b-4eed-a90a-93d4dcc533e5":{"roots":{"references":[{"attributes":{"data_source":{"id":"e7ba8d17-8433-4a85-bf39-d8ae84a0bac6","type":"ColumnDataSource"},"glyph":{"id":"894413e2-a641-4790-aaed-268eadb99cf1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f5557df5-b83d-4c23-b04c-991588281ba0","type":"Circle"},"selection_glyph":null},"id":"d1b9b767-7ff5-4785-955d-499f1468bc14","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749476,0.30901699437494723],"y":[-0.587785252292473,-0.9510565162951536]}},"id":"1c24c5f9-fced-42cc-a809-78a907c2da66","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"d90e5f32-cbc8-47fa-8690-842a69aab236","type":"LinearAxis"}],"left":[{"id":"deed35b8-e74f-43f1-83cf-5e202fa570e4","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"d90e5f32-cbc8-47fa-8690-842a69aab236","type":"LinearAxis"},{"id":"25aefd42-15c9-43a8-ba35-4edab30b2a14","type":"Grid"},{"id":"deed35b8-e74f-43f1-83cf-5e202fa570e4","type":"LinearAxis"},{"id":"a8f1de68-d90d-4cf8-8088-13baefb60a33","type":"Grid"},{"id":"6073a181-23c6-4545-a0d1-b623a7ad7540","type":"BoxAnnotation"},{"id":"ac2e4303-43bb-4f54-8085-570172ef8535","type":"GlyphRenderer"},{"id":"4c04e782-6dc0-4330-9e9d-71b3996e3223","type":"GlyphRenderer"},{"id":"d9651dfe-1dc1-46a0-be26-09e7ef3ae141","type":"GlyphRenderer"},{"id":"b6dcc38a-0525-4f7b-a13d-a1f7c63dc090","type":"GlyphRenderer"},{"id":"b6a5ca35-6f85-4bea-988a-f44265db3206","type":"GlyphRenderer"},{"id":"5cfac125-5e94-449a-a66a-dbdfdebfda2f","type":"GlyphRenderer"},{"id":"319978df-24c3-4d49-acb1-fdf9828ecdfc","type":"GlyphRenderer"},{"id":"fe6aadc3-b075-4267-819e-d291cf4be3a7","type":"GlyphRenderer"},{"id":"389c8ba6-73b7-4d09-b950-2d4831b39f8c","type":"GlyphRenderer"}],"tool_events":{"id":"cc72c9b6-d1cf-4188-9988-75bb05d370ce","type":"ToolEvents"},"tools":[{"id":"24805212-61cb-4300-b04f-14611cf6f294","type":"PanTool"},{"id":"d937e7d0-56a4-4d4b-964a-1ceb94cff4e5","type":"WheelZoomTool"},{"id":"c3c784a9-0b12-49b6-9117-13c07b330ea2","type":"BoxZoomTool"},{"id":"913510d8-6f69-4cc7-a846-c6737e6c9f37","type":"PreviewSaveTool"},{"id":"1fa941fd-f1e7-4b92-bce1-b4ee2b669a00","type":"ResizeTool"},{"id":"44076a2b-e677-4842-9b11-3b7b8ab18bf4","type":"ResetTool"},{"id":"bd860acf-e262-479c-8d7b-60e484397871","type":"HelpTool"}],"x_range":{"id":"8eb989d9-9cb2-425b-90b0-9e7393c472d2","type":"Range1d"},"y_range":{"id":"bea29950-6e1d-4849-8125-899f95f0ba68","type":"Range1d"}},"id":"042c498a-8d73-4b0a-bdcd-0998693754d2","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"042c498a-8d73-4b0a-bdcd-0998693754d2","subtype":"Figure","type":"Plot"}},"id":"1fa941fd-f1e7-4b92-bce1-b4ee2b669a00","type":"ResizeTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"f44508b4-d3a6-45f0-8e64-0479f60dae90","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f30cf00-d64e-4cf6-86d4-0a050fcac6d9","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-0.8090169943749473],"y":[0.5877852522924732]}},"id":"63fc497a-59c4-44f2-b561-99127fa9097f","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.05},"x":{"field":"x"},"y":{"field":"y"}},"id":"af64c163-3877-4128-ba72-0f72596fdd2c","type":"Circle"},{"attributes":{},"id":"1ba8130a-b2eb-43c5-9e4b-30e1feb45265","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"v ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[27]</strong>&gt;</code></p>

# %% [markdown]
# # Lattice

# %%
rows = 3
columns = 3
lattice = nx.grid_2d_graph(rows, columns)

# get the position tuple
pos = dict( (n, n) for n in self.lattice.nodes() )
labels = dict( ((i, j), i * 10 + j) for i, j in self.lattice.nodes() )
nx.draw_networkx(self.lattice, pos=pos, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e55dfbf4a40f> in <module>()
#       4
#       5 # get the position tuple
# ----> 6 pos = dict( (n, n) for n in self.lattice.nodes() )
#       7 labels = dict( ((i, j), i * 10 + j) for i, j in self.lattice.nodes() )
#       8 nx.draw_networkx(self.lattice, pos=pos, labels=labels)
#
# NameError: name 'self' is not defined
